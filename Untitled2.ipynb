# %% [markdown]
# <a href="https://colab.research.google.com/github/Danielpfs01/Desafio_Cientista_de_Dados/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv as csv

# %%
Base_Dados = pd.read_csv('BostonHousing2.csv','BostonHousing2')
Base_Dados
# Out:
# <ipython-input-11-e58cb777e126>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   Base_Dados = pd.read_csv('BostonHousing2.csv','BostonHousing2')
# <ipython-input-11-e58cb777e126>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   Base_Dados = pd.read_csv('BostonHousing2.csv','BostonHousing2')
#     crim;zn;indus;chas;nox;rm;age;dis;rad;tax;ptratio;b;lstat;medv
# 0    0.00632;18;2.31;0;0.538;6.575;65.2;4.09;1;296;...
# 1    0.02731;0;7.07;0;0.469;6.421;78.9;49.671;2;242...
# 2    0.02729;0;7.07;0;0.469;7.185;61.1;49.671;2;242...
# 3    0.03237;0;2.18;0;0.458;6.998;45.8;60.622;3;222...
# 4    0.06905;0;2.18;0;0.458;7.147;54.2;60.622;3;222...
# ..                                                 ...
# ...
